# %% [markdown]
# <a href="https://colab.research.google.com/github/hanokjoshua144/DEEP-LEARNING-6-SEM/blob/main/autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), 784))
x_test = x_test.reshape((len(x_test), 784))

input_dim = 784
encoding_dim = 32

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
decoded = Dense(input_dim, activation='sigmoid')(encoded)

autoencoder = Model(input_layer, decoded)

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(
    x_train, x_train,
    epochs=18,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)

decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))

for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# underfitting

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), 784))
x_test = x_test.reshape((len(x_test), 784))

input_layer = Input(shape=(784,))
encoded = Dense(8, activation='relu')(input_layer)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train, epochs=18, batch_size=256, shuffle=True, validation_data=(x_test, x_test))

decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))

for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# overfitting

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), 784))
x_test = x_test.reshape((len(x_test), 784))

input_layer = Input(shape=(784,))
encoded = Dense(1000, activation='relu')(input_layer)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train, epochs=18, batch_size=256, shuffle=True, validation_data=(x_test, x_test))

decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))

for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# Relu

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load data
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), 784))
x_test = x_test.reshape((len(x_test), 784))

# Set hidden layer size
hidden_layer_size = 32  # Change to 8 for underfitting, 512 for overfitting

# Build autoencoder with ReLU in both layers
input_layer = Input(shape=(784,))
encoded = Dense(hidden_layer_size, activation='relu')(input_layer)
decoded = Dense(784, activation='relu')(encoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Train model
autoencoder.fit(
    x_train, x_train,
    epochs=18,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)

# Predict reconstructed images
decoded_imgs = autoencoder.predict(x_test)

# Visualize results
n = 10
plt.figure(figsize=(20, 4))

for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(np.clip(decoded_imgs[i].reshape(28, 28), 0, 1), cmap='gray')
    ax.axis('off')

plt.show()

# %% [markdown]
# optimizer change

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt

(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), 784))
x_test = x_test.reshape((len(x_test), 784))

input_layer = Input(shape=(784,))
encoded = Dense(hidden_layer_size, activation='relu')(input_layer)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_layer, decoded)

autoencoder.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy')

autoencoder.fit(
    x_train, x_train,
    epochs=15,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)

decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()

# %% [markdown]
# Denoising Autoencoder

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt

(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), 784))
x_test = x_test.reshape((len(x_test), 784))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

hidden_layer_size = 128

input_layer = Input(shape=(784,))
encoded = Dense(hidden_layer_size, activation='relu')(input_layer)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy')

autoencoder.fit(
    x_train_noisy, x_train,
    epochs=15,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test_noisy, x_test)
)

decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(3, n, i + 1 + 2*n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

plt.show()

# %% [markdown]
# Demonstrate PCA with AE on a dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
import torch
import torch.nn as nn
import torch.optim as optim

data = load_digits()
X = data.data / 16.0

pca = PCA(n_components=16)   # reduce from 64 → 16
X_pca = pca.fit_transform(X)
X_reconstructed_pca = pca.inverse_transform(X_pca)

# %% [markdown]
# Autoencoder Model

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16)
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.Sigmoid()
        )

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon

# %% [markdown]
# Train AE

# %%
model = Autoencoder()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

X_tensor = torch.tensor(X, dtype=torch.float32)

for epoch in range(100):
    optimizer.zero_grad()
    output = model(X_tensor)
    loss = criterion(output, X_tensor)
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

with torch.no_grad():
    X_ae = model(X_tensor).numpy()

plt.figure(figsize=(10,4))

for i in range(5):
    # Original
    plt.subplot(3,5,i+1)
    plt.imshow(X[i].reshape(8,8), cmap='gray')
    plt.title("Original")

    # PCA
    plt.subplot(3,5,i+6)
    plt.imshow(X_reconstructed_pca[i].reshape(8,8), cmap='gray')
    plt.title("PCA")

    # AE
    plt.subplot(3,5,i+11)
    plt.imshow(X_ae[i].reshape(8,8), cmap='gray')
    plt.title("AE")

plt.tight_layout()
plt.show()

# %% [markdown]
# Implement Sparse AE and Contractive AE.

# %%
class SparseAE(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.Sigmoid()
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.Sigmoid()
        )

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon, z

# %% [markdown]
# Sparsity Loss (KL Divergence)

# %%
def sparse_loss(z, rho=0.05):
    rho_hat = torch.mean(z, dim=0)
    return torch.sum(rho * torch.log(rho / rho_hat) +
                     (1 - rho) * torch.log((1 - rho) / (1 - rho_hat)))

# %% [markdown]
# Training Sparse AE

# %%
model = SparseAE()
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(100):
    optimizer.zero_grad()
    output, z = model(X_tensor)

    mse_loss = nn.MSELoss()(output, X_tensor)
    kl_loss = sparse_loss(z)

    loss = mse_loss + 0.1 * kl_loss   # lambda = 0.1
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# %% [markdown]
# Contractive Autoencoder

# %%
class ContractiveAE(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(64, 16),
            nn.Sigmoid()
        )
        self.decoder = nn.Sequential(
            nn.Linear(16, 64),
            nn.Sigmoid()
        )

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon, z

# %% [markdown]
# Contractive Loss

# %%
def contractive_loss(x, z, model, lam=1e-3):
    mse = nn.MSELoss()(model.decoder(z), x)

    W = model.encoder[0].weight  # weights
    dh = z * (1 - z)             # derivative of sigmoid

    contractive = torch.sum((dh ** 2) @ (W ** 2).sum(dim=1))

    return mse + lam * contractive

# %% [markdown]
# Training Contractive AE

# %%
model = ContractiveAE()
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(100):
    optimizer.zero_grad()
    x_recon, z = model(X_tensor)

    loss = contractive_loss(X_tensor, z, model)
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# %% [markdown]
# OBSERVATIONS
#
# PCA vs Autoencoder – Observations
# PCA performs linear dimensionality reduction, while Autoencoder (AE) performs non-linear reduction.
# PCA captures only global variance, whereas AE captures complex patterns and structures.
# AE provides better reconstruction quality than PCA, especially for non-linear data.
# PCA is faster and computationally cheaper, while AE requires training time.
# PCA components are orthogonal, but AE features are learned representations (not necessarily orthogonal).
# AE is more flexible and powerful, but PCA is more interpretable.
#
# Sparse Autoencoder – Observations
# Sparse AE enforces most hidden neurons to remain inactive (close to zero).
# Only a small subset of neurons activates, leading to efficient feature representation.
# It learns distinct and meaningful features from the data.
# Reduces redundancy and improves feature interpretability.
# Prevents trivial identity mapping (copying input directly).
# Useful for feature extraction and representation learning.
#
#
#
# Contractive Autoencoder – Observations
# Contractive AE produces robust and stable representations.
# It minimizes sensitivity to small input perturbations (noise).
# Learns a smooth latent space (similar inputs → similar encodings).
# Improves generalization by enforcing local invariance.
# More resistant to overfitting compared to basic AE.
# Useful in denoising and manifold learning.
